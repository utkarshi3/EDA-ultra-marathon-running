# %%
#https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running?resource=download

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import random

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\birla\AppData\Local\Temp\ipykernel_3400\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
#See what's been imported - first 4 rows

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
#last 4 rows of data

# %%
df.tail()
# Out:
#          Year of event Event dates                                Event name  \
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 7461190                  65km                          2           4:33:20 h
# 7461191                  65km                          2           6:05:15 h
# 7461192                   24h                          3          241.000 km
# 7461193                   24h                          3          228.000 km
# 7461194                   24h                          3          224.000 km
#
# ...

# %%
 #data types of all columns

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#cleaning data

# %%
#Only want USA races, distance = 50km or 50mi, 2020

# %%
#Step 1: Show distance = 50km or 50mi

# %%
df[(df['Event distance/length'] == "50km")]
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'] == "50mi")]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combining both

df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Step 2: Year = 2020

df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
# Checking the athelete's country

# %%
df[(df['Athlete country'] == "USA")].head()
# Out:
#     Year of event Event dates                                     Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9           9:53:05 h
# 58                  50mi                          9          11:38:17 h
# 59                  50mi                          9          11:56:35 h
# 60                  50mi                          9          12:32:16 h
# 61                  50mi                          9          12:39:36 h
#
# ...

# %%
df[df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Step 3: Combining 3 conditions

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
#Remove (USA) from event name

# %%
df2["Event name"] = df2["Event name"].str.split("(").str.get(0)
# Out:
# C:\Users\birla\AppData\Local\Temp\ipykernel_3400\3464257636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"] = df2["Event name"].str.split("(").str.get(0)

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
#Remove 'h' from Athlete Performance

# %%
df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)
# Out:
# C:\Users\birla\AppData\Local\Temp\ipykernel_3400\1376561742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#clean up athlete's age

# %%
df2["Athlete age"] = 2020 - df2["Athlete year of birth"]
# Out:
# C:\Users\birla\AppData\Local\Temp\ipykernel_3400\1209317780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete age"] = 2020 - df2["Athlete year of birth"]

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#drop columns - Year of event, Athlete club, Athlete country, Athlete year of birth,

# %%
df2 = df2.drop(['Year of event', 'Athlete club', 'Athlete country', 'Athlete year of birth'], axis = 1)

# %%
df2.head()
# Out:
#         Event dates                                Event name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# ...

# %%
#clean up values

# %%
df2.isna().sum()
# Out:
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete age category         217
# Athlete average speed          0
# Athlete ID                     0
# Athlete age                  233
# dtype: int64

# %%
# dropping athlete age category

df2 = df2.drop(['Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#         Event dates                                Event name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete age
# ...

# %%
df2.isna().sum()
# Out:
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete age                  233
# dtype: int64

# %%
df2[df2["Athlete age"].isna() == 1]
# Out:
#         Event dates                           Event name  \
# 2547794  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...             ...                                  ...
# 2746543  17.10.2020     Black River Trail Classic 50 Km
# 2749869  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985  10.10.2020      Man Against Horse 50 Mile Race
# 2755994  10.10.2020      Man Against Horse 50 Mile Race
# 2755997  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2547794                  50km                         57             6:10:30
# 2551331                  50km                         54             4:46:34
# ...

# %%
# dropping null values

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 9)

# %%
df2.head()
# Out:
#         Event dates                                Event name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#         Athlete gender Athlete average speed  Athlete ID  Athlete age
# ...

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete age]
# Index: []

# %%
#reset index

df2.reset_index(drop = True)
# Out:
#       Event dates                                Event name  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition
# 1      02.02.2020  West Seattle Beach Run - Winter Edition
# 2      02.02.2020  West Seattle Beach Run - Winter Edition
# 3      02.02.2020  West Seattle Beach Run - Winter Edition
# 4      02.02.2020  West Seattle Beach Run - Winter Edition
# ...           ...                                       ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# 0                      50km                         20             3:17:55
# 1                      50km                         20             4:02:32
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete age                  float64
# dtype: object

# %%
df2["Athlete age"] = df2["Athlete age"].astype(int)

# %%
df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)

# %%
df2.dtypes
# Out:
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete age                    int32
# dtype: object

# %%
df2.head()
# Out:
#         Event dates                                Event name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
#         Athlete gender  Athlete average speed  Athlete ID  Athlete age
# ...

# %%
#rename columns

# %%
df2 = df2.rename(columns = {'Event dates' : 'event_date',
                            'Event name': 'event_name',
                            'Event distance/length': 'event_distance',
                            'Event number of finishers': 'event_no_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'avg_speed',
                            'Athlete ID': 'athlete_id',
                            'Athlete age': 'athlete_age'})

# %%
df2.head()
# Out:
#          event_date                                event_name event_distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition            50km
#
#          event_no_finishers athlete_performance athlete_gender  avg_speed  \
# 2539945                  20             3:17:55              M     15.158
# 2539946                  20             4:02:32              M     12.369
# 2539947                  20             4:07:57              M     12.099
# 2539948                  20             4:22:02              M     11.449
# 2539949                  20             4:27:34              M     11.212
#
#          athlete_id  athlete_age
# ...

# %%
#reordering the columns

# %%
 df3 = df2[["event_date","event_name","event_distance","event_no_finishers","athlete_performance","athlete_gender","avg_speed","athlete_id","athlete_age"]]

# %%
df3.head()
# Out:
#          event_date                                event_name event_distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition            50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition            50km
#
#          event_no_finishers athlete_performance athlete_gender  avg_speed  \
# 2539945                  20             3:17:55              M     15.158
# 2539946                  20             4:02:32              M     12.369
# 2539947                  20             4:07:57              M     12.099
# 2539948                  20             4:22:02              M     11.449
# 2539949                  20             4:27:34              M     11.212
#
#          athlete_id  athlete_age
# ...

# %%
df3[df3["athlete_id"] == 34861]
# Out:
#          event_date                            event_name event_distance  \
# 2541541  01.02.2020               Fort Ord 50K Trail Run            50km
# 2548809  25.01.2020            Paramount Ranch Trail Run            50km
# 2612370  29.02.2020                  Sycamore Canyon 50k            50km
# 2694862  27.12.2020               Doce Canyon 50 km Race            50km
# 2698823  19.12.2020  Running Is Not Closed Run - Race 11            50km
# 2707902  05.12.2020                Lake Hughes 50km Race            50km
#
#          event_no_finishers athlete_performance athlete_gender  avg_speed  \
# 2541541                  76             7:30:20              M      6.662
# 2548809                  31             5:52:46              M      8.504
# 2612370                  52             8:00:26              M      6.244
# 2694862                  15             7:19:27              M      6.827
# 2698823                  29             6:36:33              M      7.565
# ...

# %%
# checking if there's any duplicated value in athlete id column

# %%
duplicate_values = df3["athlete_id"].duplicated()
for value in duplicate_values:
    if value:
        print(value)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
duplicated_athlete_ids = df3[df3["athlete_id"].duplicated()]["athlete_id"]
for athlete_id in duplicated_athlete_ids:
    print(athlete_id)
# Out:
# 150288
# 25574
# 11979
# 343803
# 24307
# 84429
# 47221
# 260741
# 19228
# 67092
# 34861
# 810742
# 54512
# 810625
# 180706
# 1162
# 64556
# 12278
# 48473
# 55757
# 33819
# 751750
# 67094
# 194405
# 33656
# 657403
# 746375
# 24307
# 343803
# 23418
# 202456
# 143
# 46402
# 45316
# 84429
# 55249
# 55762
# 364678
# 126098
# 109066
# 229856
# 19214
# 19677
# 33936
# 341514
# 46421
# 48155
# 12236
# 74548
# 11736
# 753889
# 180706
# 19237
# 37024
# 48052
# 811921
# 54585
# 54584
# 216734
# 47500
# 54536
# 19576
# 40720
# 54546
# 67062
# 141
# 50937
# 54590
# 653089
# 54569
# 470774
# 143
# 42400
# 216632
# 35562
# 186772
# 810742
# 345917
# 202038
# 118249
# 208456
# 55583
# 34844
# 140595
# 55540
# 702539
# 13541
# 118230
# 126877
# 55471
# 65127
# 217568
# 33523
# 55466
# 388715
# 42353
# 706814
# 274845
# 812319
# 31281
# 813684
# 45299
# 39650
# 73416
# 367571
# 67944
# 50901
# 67945
# 13660
# 39629
# 67959
# 114870
# 67957
# 61476
# 34733
# 46032
# 103463
# 73348
# 141
# 143
# ...

# %%
# remove duplicate values in ProductID column

# %%
df = df.drop_duplicates(subset=['athlete_id'], keep='first')
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [162], in <cell line: 1>()
# ----> 1 df = df.drop_duplicates(subset=['athlete_id'], keep='first')
#       2 print(df)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:6566, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6563 inplace = validate_bool_kwarg(inplace, "inplace")
#    6564 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6566 result = self[-self.duplicated(subset, keep=keep)]
#    6567 if ignore_index:
#    6568     result.index = default_index(len(result))
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:6698, in DataFrame.duplicated(self, subset, keep)
#    6696 diff = set(subset) - set(self.columns)
#    6697 if diff:
# -> 6698     raise KeyError(Index(diff))
#    6700 if len(subset) == 1 and self.columns.is_unique:
# ...

# %%
# charts and graphs

# %%
sns.histplot(df3["athlete_gender"])

# %%
sns.histplot(df3, x = "event_distance", hue = "athlete_gender")

# %%
sns.displot(df3[df3["event_distance"] == "50mi"]["avg_speed"])

# %%
sns.violinplot(data = df3, x = "event_distance", y = "avg_speed", hue = "athlete_gender", split = True, inner = "quart", linewidth = 1)

# %%
sns.lmplot(data = df3, x = "athlete_age", y = "avg_speed", hue = "athlete_gender")

# %%
# questions -

# %%
# difference in speed for the 50km, 50mi male to female

# %%
df3.groupby(["event_distance","athlete_gender"])["avg_speed"].mean()

# %%
# what age group is best for 50 km

# %%
df3.query("event_distance == '50km'").groupby("athlete_age")["avg_speed"].agg(["mean","count"]).sort_values("mean", ascending = False).query("count>19")

# %%
# what age group is best for 50 mi

# %%
df3.query("event_distance == '50mi'").groupby("athlete_age")["avg_speed"].agg(["mean","count"]).sort_values("mean", ascending = False).query("count>19").head(10)

# %%
# what age group is worst for 50 mi (show 10)

# %%
df3.query("event_distance == '50mi'").groupby("athlete_age")["avg_speed"].agg(["mean","count"]).sort_values("mean", ascending = True).query("count>9").head(10)

# %%
df3.dtypes

# %%
#seasons for the data --> runner slower in summer than winter?

#spring 3-5
#summer 6-8
#fall 9-11
#winter 12 -2

#split between two decimals

# %%
df3["event_month"] = df3["event_date"].str.split(".").str.get(1).astype(int)

# %%
df3["event_season"] = df3["event_month"].apply(lambda x: "Winter" if x>11 else "Fall" if x>8 else "Summer" if x>5 else "Spring" if x>2 else "Winter")

# %%
df3.tail()

# %%
df3.groupby("event_season")["avg_speed"].agg(["mean","count"]).sort_values("mean",ascending=False)

# %%
# show only 50mi

# %%
df3.query("event_distance == '50mi'").groupby("event_season")["avg_speed"].agg(["mean","count"]).sort_values("mean",ascending=False)
